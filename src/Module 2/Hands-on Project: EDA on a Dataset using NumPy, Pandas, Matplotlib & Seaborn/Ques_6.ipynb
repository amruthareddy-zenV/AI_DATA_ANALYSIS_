# %%
# Title: Correlation Analysis
# Description: Find the correlation between different features and visualize using a heatmap.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame (replace with your actual data)
data = {
    'feature1': [1, 2, 3, 4, 5],
    'feature2': [5, 4, 3, 2, 1],
    'feature3': [2, 3, 5, 1, 4],
    'feature4': [4, 1, 2, 5, 3]
}
df = pd.DataFrame(data)

# 1. Calculate correlation matrix
corr_matrix = df.corr()

# 2. Visualize with heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, 
            annot=True, 
            cmap='coolwarm', 
            vmin=-1, 
            vmax=1, 
            linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.show()

# 3. Optional: Display correlation matrix as table
print("\nCorrelation Matrix:")
print(corr_matrix)
# Out:
# Correlation Matrix:
#           feature1  feature2  feature3  feature4
# feature1       1.0      -1.0       0.2       0.2
# feature2      -1.0       1.0      -0.2      -0.2
# feature3       0.2      -0.2       1.0      -0.7
# feature4       0.2      -0.2      -0.7       1.0
