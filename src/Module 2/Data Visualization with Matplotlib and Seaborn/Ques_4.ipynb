# %%
# Basic Seaborn Bar Plot
# Description: Using Seaborn, plot the same bar plot from Question 1 to compare the sales data.
import seaborn as sns
import matplotlib.pyplot as plt

# Data
products = ['A', 'B', 'C', 'D', 'E']
sales = [23, 75, 57, 90, 65]  # Sales in thousands

# Set Seaborn style
sns.set(style="whitegrid")  # Use white background with grid

# Create the bar plot
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=products, y=sales, palette="Blues_d")

# Add titles and labels
plt.title('Product Sales (in thousands)', fontsize=14, pad=20)
plt.xlabel('Products', fontsize=12)
plt.ylabel('Sales (thousands)', fontsize=12)

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 9), 
                textcoords='offset points',
                fontsize=10)

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4073/2766082514.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=products, y=sales, palette="Blues_d")
